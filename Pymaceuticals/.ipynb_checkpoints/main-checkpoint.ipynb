# %% [markdown]
# ## Observations and Insights
# #### Add your analysis here
# ---
# 1. The heavier the mouse, the larger the tumor
# 2. Capomulin and Ramicane appear to be the most effective at reducing tumor volume
# 3. The larger the tumor, the greater the standard deviation.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)
# mouse_metadata.head()
# study_results.head()

# %%
# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
merge_df#.head()

# Display the data table for preview
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Check the number of mice.
numberofmice = len(merge_df["Mouse ID"].unique())
numberofmice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
merge_df[merge_df.duplicated(subset=['Mouse ID','Timepoint'], keep=False)]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
# dropped_df = merge_df.drop_duplicates(['Mouse ID','Timepoint'],keep= False)
# dropped_df#.head()
dropped_df = merge_df[merge_df['Mouse ID'] != 'g989']
dropped_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Check the number of mice in the clean DataFrame.
numberofmice2 = len(dropped_df["Mouse ID"].unique())
numberofmice2
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use this straighforward method, create multiple series and put them all in a dataframe at the end. ['Tumor Volume (mm3)']
meandata = dropped_df[['Drug Regimen','Tumor Volume (mm3)']].rename(columns={"Tumor Volume (mm3)": "Average Tumor Volume"})
meandata
mean_df = meandata.groupby(['Drug Regimen']).mean()
# mean_df
mediandata = dropped_df[['Drug Regimen','Tumor Volume (mm3)']].rename(columns={"Tumor Volume (mm3)": "Median Tumor Volume"})
median_df = mediandata.groupby(['Drug Regimen']).median()
# median_df
vardata = dropped_df[['Drug Regimen','Tumor Volume (mm3)']].rename(columns={"Tumor Volume (mm3)": "Variance of Tumor Volume"})
var_df = vardata.groupby(['Drug Regimen']).var()
# var_df
stddata = dropped_df[['Drug Regimen','Tumor Volume (mm3)']].rename(columns={"Tumor Volume (mm3)": "StdDev Tumor Volume"})
std_df = stddata.groupby(['Drug Regimen']).std()
# std_df
semdata = dropped_df[['Drug Regimen','Tumor Volume (mm3)']].rename(columns={"Tumor Volume (mm3)": "StdErr Tumor Volume"})
sem_df = semdata.groupby(['Drug Regimen']).sem()
# sem_df
# median_df = dropped_df.groupby(['Drug Regimen']).median()
# var_df = dropped_df.groupby(['Drug Regimen']).var()
# std_df = dropped_df.groupby(['Drug Regimen']).std()
# sem_df = dropped_df.groupby(['Drug Regimen']).sem()
summarystats = pd.merge(mean_df, median_df, on="Drug Regimen")
summarystats = pd.merge(summarystats, var_df, on="Drug Regimen")
summarystats = pd.merge(summarystats, std_df, on="Drug Regimen")
summarystats = pd.merge(summarystats, sem_df, on="Drug Regimen")
# , , std_df, sem_df,
# summarystats = pd.DataFrame([mean_df, median_df, var_df, std_df, sem_df])
summarystats
# Out:
#               Average Tumor Volume  Median Tumor Volume  \
# Drug Regimen
# Capomulin                40.675741            41.557809
# Ceftamin                 52.591172            51.776157
# Infubinol                52.884795            51.820584
# Ketapril                 55.235638            53.698743
# Naftisol                 54.331565            52.509285
# Placebo                  54.033581            52.288934
# Propriva                 52.320930            50.446266
# Ramicane                 40.216745            40.673236
# Stelasyn                 54.233149            52.431737
# Zoniferol                53.236507            51.818479
#
#               Variance of Tumor Volume  StdDev Tumor Volume  \
# Drug Regimen
# Capomulin                    24.947764             4.994774
# Ceftamin                     39.290177             6.268188
# Infubinol                    43.128684             6.567243
# Ketapril                     68.553577             8.279709
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use method to produce everything with a single groupby function
summarydata = dropped_df.groupby(['Drug Regimen'])
summarydata.head()
summarymean = summarydata["Tumor Volume (mm3)"].mean()
summarymedian = summarydata["Tumor Volume (mm3)"].median()
summaryvar = summarydata["Tumor Volume (mm3)"].var()
summarystd = summarydata["Tumor Volume (mm3)"].std()
summarysem = summarydata["Tumor Volume (mm3)"].sem()
summarystats2 = pd.DataFrame({"Average Tumor Volume": summarymean, 
                              "Median Tumor Volume":summarymedian, 
                              "Variance of Tumor Volume":summaryvar, 
                              "StdDev Tumor Volume": summarystd, 
                              "StdErr Tumor Volume": summarysem})
summarystats2
# Out:
#               Average Tumor Volume  Median Tumor Volume  \
# Drug Regimen
# Capomulin                40.675741            41.557809
# Ceftamin                 52.591172            51.776157
# Infubinol                52.884795            51.820584
# Ketapril                 55.235638            53.698743
# Naftisol                 54.331565            52.509285
# Placebo                  54.033581            52.288934
# Propriva                 52.320930            50.446266
# Ramicane                 40.216745            40.673236
# Stelasyn                 54.233149            52.431737
# Zoniferol                53.236507            51.818479
#
#               Variance of Tumor Volume  StdDev Tumor Volume  \
# Drug Regimen
# Capomulin                    24.947764             4.994774
# Ceftamin                     39.290177             6.268188
# Infubinol                    43.128684             6.567243
# Ketapril                     68.553577             8.279709
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
bardata = dropped_df.pivot_table(index=['Drug Regimen'], aggfunc='size')
bardata
graph = bardata.plot.bar(rot=90,title="Number of Mice per Drug",)
graph.set_ylabel('Number of Mice')
# Out:
# Text(0, 0.5, 'Number of Mice')

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
yaxis = dropped_df['Drug Regimen'].value_counts()
# yaxis
xaxis = dropped_df['Drug Regimen'].unique()
# xaxis
plt.bar(xaxis, yaxis)
plt.xticks(rotation=90)
plt.ylabel('# of Data Points')
# plt.xlabel('')
plt.title('# of Data Points per Drug')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
piedata = dropped_df.pivot_table(index=['Sex'], aggfunc='size')
piedata
graph = piedata.plot.pie(title='Sex of Mice',autopct='%1.1f%%')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
yaxis = dropped_df['Sex'].value_counts()
# yaxis
# xaxis = dropped_df['Drug Regimen'].unique()
# xaxis
plt.pie(yaxis, labels=['Male','Female'],autopct='%1.1f%%')
# plt.xticks(rotation=90)
# plt.ylabel('# of Data Points')
# # plt.xlabel('')
plt.title('Sex of Mice')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across each of the treatment regimens: 
# Start by getting the last (greatest) timepoint for each mouse
tumorgrouped_df = dropped_df.groupby('Mouse ID')['Timepoint'].max()
tumorgrouped_df#.head()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
mergedtumor_df = pd.merge(tumorgrouped_df, dropped_df, on=["Mouse ID","Timepoint"])
mergedtumor_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put 4 treatment names into a list for use with a for loop (and later for plot labels)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create a empty list to fill with tumor vol data (for plotting) (hint: each element of the list will be series)
tumor_vol_list = []
# templist = []

# For each treatment in the list, calculate the IQR and quantitatively 
# determine if there are any potential outliers. 
for drug in treatment_list:
    # Locate the rows which contain mice on each drug and get the tumor 
    row = mergedtumor_df[mergedtumor_df['Drug Regimen'] == drug]
    row = row['Tumor Volume (mm3)'].tolist()
#     print(templist)
    # add subset to tumor volume data list
    tumor_vol_list.append(row)
    # Determine outliers using upper and lower bounds
#     quartiles = tumor_vol_list.quantile([.25,.5,.75])
#     lowerq = quartiles[0.25]
#     upperq = quartiles[0.75]
#     iqr = upperq - lowerq
#     lower_bound = lowerq - (1.5*iqr)
#     upper_bound = upperq + (1.5*iqr)
#     print(f"The lower quartile of {drug} is: {lowerq}")
#     print(f"The upper quartile of {drug} is: {upperq}")
#     print(f"The interquartile range of {drug} is: {iqr}")
#     print(f"The the median of {drug} is: {quartiles[0.5]} ")
#     print(f"Values below {lower_bound} could be outliers.")
#     print(f"Values above {upper_bound} could be outliers.")
# tumor_vol_list

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume per Drug Regimen')
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(tumor_vol_list, labels=["Capomulin","Ramicane","Infubinol","Ceftamin",])
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
line_df = dropped_df[dropped_df["Mouse ID"]=="l509"]
# line_df
# line_df = line_df[['Timepoint','Tumor Volume (mm3)']]
graph = line_df.plot.line(x='Timepoint', y='Tumor Volume (mm3)',title='Tumor Volume over Time for Mouse l509')
graph.set_ylabel("Tumor Volume")
# Out:
# Text(0, 0.5, 'Tumor Volume')

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
scatter_df = dropped_df[dropped_df["Drug Regimen"]=="Capomulin"]
scatterdata = scatter_df.groupby("Mouse ID").mean()
scatterdata.plot.scatter(x='Weight (g)', y='Tumor Volume (mm3)',title='Average Tumor Volume per Weight for Capomulin')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
from scipy.stats import linregress

x_values = scatterdata['Weight (g)']
y_values = scatterdata['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Average Tumor Volume per Weight for Capomulin')
plt.show()
